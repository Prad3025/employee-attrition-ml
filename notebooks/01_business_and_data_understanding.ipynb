# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
os.listdir()
# Out:
# ['.config', 'sample_data']

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.listdir('/content/drive/MyDrive/EmployeeAttrition')
# Out:
# ['Employee_Dataset.csv']

# %%
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/EmployeeAttrition/Employee_Dataset.csv')

# %%
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df["Attrition"].value_counts()
# Out:
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64

# %%
df["Attrition"].value_counts(normalize=True)
# Out:
# Attrition
# No     0.838776
# Yes    0.161224
# Name: proportion, dtype: float64

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Initial Dataset Findings
#
# - Total employees: 1,470
# - Total features: 35
# - Employees with no attrition: 1,233
# - Employees with attrition: 237
# - Overall attrition rate: 16.12%
# - Overall non-attrition rate: 83.88%
#
# The dataset contains both numerical and categorical employee attributes.
# These attributes will be analyzed to identify factors associated with
# employee attrition.

# %%
df.columns.to_list()
# Out:
# ['Age',
#  'Attrition',
#  'BusinessTravel',
#  'DailyRate',
#  'Department',
#  'DistanceFromHome',
#  'Education',
#  'EducationField',
#  'EmployeeCount',
#  'EmployeeNumber',
#  'EnvironmentSatisfaction',
#  'Gender',
#  'HourlyRate',
#  'JobInvolvement',
#  'JobLevel',
#  'JobRole',
#  'JobSatisfaction',
#  'MaritalStatus',
#  'MonthlyIncome',
#  'MonthlyRate',
#  'NumCompaniesWorked',
#  'Over18',
#  'OverTime',
#  'PercentSalaryHike',
#  'PerformanceRating',
#  'RelationshipSatisfaction',
#  'StandardHours',
#  'StockOptionLevel',
#  'TotalWorkingYears',
#  'TrainingTimesLastYear',
#  'WorkLifeBalance',
#  'YearsAtCompany',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager']

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
schema=pd.DataFrame({
    "Columns": df.columns,
    "DataTypes":df.dtypes.astype(str),
    "Non-Null-Count":df.notnull().sum(),
    "Unique-values":df.nunique()
})
print(schema)
# Out:
#                                            Columns DataTypes  Non-Null-Count  \
# Age                                            Age     int64            1470
# Attrition                                Attrition    object            1470
# BusinessTravel                      BusinessTravel    object            1470
# DailyRate                                DailyRate     int64            1470
# Department                              Department    object            1470
# DistanceFromHome                  DistanceFromHome     int64            1470
# Education                                Education     int64            1470
# EducationField                      EducationField    object            1470
# EmployeeCount                        EmployeeCount     int64            1470
# EmployeeNumber                      EmployeeNumber     int64            1470
# EnvironmentSatisfaction    EnvironmentSatisfaction     int64            1470
# ...

# %%
schema[schema["Unique-values"] == 1]
# Out:
#                      Columns DataTypes  Non-Null-Count  Unique-values
# EmployeeCount  EmployeeCount     int64            1470              1
# Over18                Over18    object            1470              1
# StandardHours  StandardHours     int64            1470              1

# %%
df[["EmployeeNumber"]].head()
# Out:
#    EmployeeNumber
# 0               1
# 1               2
# 2               4
# 3               5
# 4               7

# %%
df["Attrition"].value_counts()
# Out:
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64

# %%
df["Attrition"].value_counts(normalize=True)*100
# Out:
# Attrition
# No     83.877551
# Yes    16.122449
# Name: proportion, dtype: float64

# %%
df["EmployeeNumber"].nunique()
# Out:
# 1470

# %%
len(df)
# Out:
# 1470

# %% [markdown]
# Numpy

# %%
import numpy as np

# %%
numbers=np.array([10,20,30,40,50])
numbers
# Out:
# array([10, 20, 30, 40, 50])

# %%
type(numbers)
# Out:
# numpy.ndarray

# %%
numbers.ndim
numbers.shape
# Out:
# (5,)

# %%
matrix=np.array([
    [10,20,30],
    [40,50,60]
])
matrix.ndim
matrix.shape
# Out:
# (2, 3)

# %%
ages = df["Age"].to_numpy()

print("Type:", type(ages))
print("Dimensions:", ages.ndim)
print("Shape:", ages.shape)
print("Size:", ages.size)
print("Average Age:", np.mean(ages))
print("Minimum Age:", np.min(ages))
print("Maximum Age:", np.max(ages))
print("Median Age:", np.median(ages))
# Out:
# Type: <class 'numpy.ndarray'>
# Dimensions: 1
# Shape: (1470,)
# Size: 1470
# Average Age: 36.923809523809524
# Minimum Age: 18
# Maximum Age: 60
# Median Age: 36.0

# %%
employees_above_40 = ages[ages > 40]

print("Employees above 40:", employees_above_40.size)
# Out:
# Employees above 40: 465

# %%
employees_below_30 = ages[ages < 30]

print("Employees below 30:", employees_below_30.size)
# Out:
# Employees below 30: 326

# %%
matrix = np.array([
    [10, 20, 30],
    [40, 50, 60]
])

print("Column sums:", np.sum(matrix, axis=0))
print("Row sums:", np.sum(matrix, axis=1))
print("Column means:", np.mean(matrix, axis=0))
print("Row means:", np.mean(matrix, axis=1))
# Out:
# Column sums: [50 70 90]
# Row sums: [ 60 150]
# Column means: [25. 35. 45.]
# Row means: [20. 50.]

# %% [markdown]
# Pandas

# %%
import pandas as pd

# %%
print("DataFrame type:")
print(type(df))

print("\nShape:")
print(df.shape)

print("\nFirst 5 rows:")
display(df.head())

print("\nLast 5 rows:")
display(df.tail())

print("\nColumns:")
print(df.columns.tolist())

print("\nIndex:")
print(df.index)

print("\nData types:")
print(df.dtypes)

print("\nInformation:")
df.info()

print("\nStatistics:")
display(df.describe())
# Out:
# DataFrame type:
# <class 'pandas.core.frame.DataFrame'>
#
# Shape:
# (1470, 35)
#
# First 5 rows:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# ...

# %%
df["Age"]
# Out:
# 0       41
# 1       49
# 2       37
# 3       33
# 4       27
#         ..
# 1465    36
# 1466    39
# 1467    27
# 1468    49
# 1469    34
# Name: Age, Length: 1470, dtype: int64

# %%
df[["Age", "MonthlyIncome", "YearsAtCompany"]].head()
# Out:
#    Age  MonthlyIncome  YearsAtCompany
# 0   41           5993               6
# 1   49           5130              10
# 2   37           2090               0
# 3   33           2909               8
# 4   27           3468               2

# %%
df.iloc[0]
# Out:
# Age                                      41
# Attrition                               Yes
# BusinessTravel                Travel_Rarely
# DailyRate                              1102
# Department                            Sales
# DistanceFromHome                          1
# Education                                 2
# EducationField                Life Sciences
# EmployeeCount                             1
# EmployeeNumber                            1
# EnvironmentSatisfaction                   2
# Gender                               Female
# HourlyRate                               94
# JobInvolvement                            3
# JobLevel                                  2
# JobRole                     Sales Executive
# JobSatisfaction                           4
# MaritalStatus                        Single
# MonthlyIncome                          5993
# MonthlyRate                           19479
# NumCompaniesWorked                        8
# ...

# %%
df.loc[0,"Age"]
# Out:
# np.int64(41)

# %%
df[df["OverTime"]=="Yes"]
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 6      59        No      Travel_Rarely       1324  Research & Development
# 11     29        No      Travel_Rarely        153  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1450   35        No      Travel_Rarely       1146         Human Resources
# 1456   35        No  Travel_Frequently       1199  Research & Development
# 1459   29        No      Travel_Rarely       1378  Research & Development
# 1461   50       Yes      Travel_Rarely        410                   Sales
# 1467   27        No      Travel_Rarely        155  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df["Attrition"].value_counts()
# Out:
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64

# %%
df["Attrition"].value_counts(normalize=True)
# Out:
# Attrition
# No     0.838776
# Yes    0.161224
# Name: proportion, dtype: float64

# %%
df["Attrition"].value_counts(normalize=True)*100
# Out:
# Attrition
# No     83.877551
# Yes    16.122449
# Name: proportion, dtype: float64

# %%
df.sort_values("MonthlyIncome")
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 513    20       Yes      Travel_Rarely       1362  Research & Development
# 727    18        No         Non-Travel        287  Research & Development
# 764    28        No      Travel_Rarely       1144                   Sales
# 1338   30       Yes      Travel_Rarely        945                   Sales
# 1365   29       Yes  Travel_Frequently        746                   Sales
# ...   ...       ...                ...        ...                     ...
# 568    55       Yes      Travel_Rarely        725  Research & Development
# 165    50        No      Travel_Rarely       1452  Research & Development
# 851    56        No      Travel_Rarely        718  Research & Development
# 746    41        No         Non-Travel        247  Research & Development
# 190    52        No      Travel_Rarely        699  Research & Development
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
df.sort_values("MonthlyIncome",ascending=False).head(10)
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 190    52        No      Travel_Rarely        699  Research & Development
# 746    41        No         Non-Travel        247  Research & Development
# 851    56        No      Travel_Rarely        718  Research & Development
# 165    50        No      Travel_Rarely       1452  Research & Development
# 568    55       Yes      Travel_Rarely        725  Research & Development
# 918    51        No  Travel_Frequently        237                   Sales
# 749    52       Yes      Travel_Rarely        266                   Sales
# 1242   40        No      Travel_Rarely        611                   Sales
# 898    43        No      Travel_Rarely        920  Research & Development
# 956    56        No      Travel_Rarely        206         Human Resources
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# 190                  1          4     Life Sciences              1
# ...

# %%
df["AnualIncome"]=df["MonthlyIncome"]*12

# %%
df[["AnualIncome","MonthlyIncome"]].head(5)
# Out:
#    AnualIncome  MonthlyIncome
# 0        71916           5993
# 1        61560           5130
# 2        25080           2090
# 3        34908           2909
# 4        41616           3468
